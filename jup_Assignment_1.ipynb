# %% [markdown]
# # ASSIGNMENT 1 (Five Tasks) BY
# ## NAME = PRASHANT NAGESH GAVLI
# ## CLASS = PYTHON AI & ML
# ## COLLAGE = GPH

# %%
"""✅ Task 1: Display Specific Rows and Columns

Use iloc to display the first 3 rows and only the 'Name' and 'Marks' columns.

✅ Task 2: Count Gender Distribution

Use value_counts() to find out how many males and females are in the dataset.

✅ Task 3: Find Missing Data

Show all rows where the 'Marks' or 'City' column has null (missing) values.

✅ Task 4: Fill Missing Marks

Replace all missing values in the 'Marks' column with the average marks of other students.

✅ Task 5: Filter and Display High Scorers

Use loc to display the name and marks of all students who scored more than 80."""

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df=pd.read_csv('validation.csv')

# %%
df
# Out:
#         Age  Grade  Gender      Race  SES_Quartile ParentalEducation  \
# 0        14      9  Female  Hispanic             3       SomeCollege
# 1        17     12  Female     White             4       SomeCollege
# 2        17     12  Female     Other             2                HS
# 3        15     10    Male     White             4       SomeCollege
# 4        18     12    Male     Black             3                HS
# ...     ...    ...     ...       ...           ...               ...
# 999224   18     12    Male     White             3                HS
# 999225   18     12    Male  Hispanic             2                HS
# 999226   16     11    Male     Asian             1        Bachelors+
# 999227   17     12  Female     White             4       SomeCollege
# 999228   17     12    Male     White             3               <HS
#
#        SchoolType    Locale  TestScore_Math  TestScore_Reading  ...       GPA  \
# ...

# %% [markdown]
#  ### Task 2: Count Gender Distribution

# %%
#As i do not have "Name" and "Marks" columns in my dataset therefore i have used "Age" and "Gender" as columns
df.iloc[0:3,[0,2]]
# Out:
#    Age  Gender
# 0   14  Female
# 1   17  Female
# 2   17  Female

# %% [markdown]
# ### Task 1: Display Specific Rows and Columns

# %%
df = pd.read_csv('validation.csv')
df
# Out:
#         Age  Grade  Gender      Race  SES_Quartile ParentalEducation  \
# 0        14      9  Female  Hispanic             3       SomeCollege
# 1        17     12  Female     White             4       SomeCollege
# 2        17     12  Female     Other             2                HS
# 3        15     10    Male     White             4       SomeCollege
# 4        18     12    Male     Black             3                HS
# ...     ...    ...     ...       ...           ...               ...
# 999224   18     12    Male     White             3                HS
# 999225   18     12    Male  Hispanic             2                HS
# 999226   16     11    Male     Asian             1        Bachelors+
# 999227   17     12  Female     White             4       SomeCollege
# 999228   17     12    Male     White             3               <HS
#
#        SchoolType    Locale  TestScore_Math  TestScore_Reading  ...       GPA  \
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    509317
# Male      489912
# Name: count, dtype: int64

# %% [markdown]
# ### Task 3: Find Missing Data

# %%
#i dont have "marks' and 'city' column in my dataset, therefore i will use 'SchoolType' and 'Locale' from my data
df[df['SchoolType'].isnull() | df['Locale'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Grade, Gender, Race, SES_Quartile, ParentalEducation, SchoolType, Locale, TestScore_Math, TestScore_Reading, TestScore_Science, GPA, AttendanceRate, StudyHours, InternetAccess, Extracurricular, PartTimeJob, ParentSupport, Romantic, FreeTime, GoOut]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Task 4: Fill Missing Marks

# %%
#As i do not have "Marks" column in my dataset therefore i have used "StudyHours" column

# %%
df['StudyHours'].fillna(df['StudyHours'].mean())
# Out:
# 0         1.409700
# 1         1.112296
# 2         1.214927
# 3         0.155258
# 4         0.908776
#             ...
# 999224    0.295662
# 999225    0.916343
# 999226    1.142396
# 999227    1.023759
# 999228    0.850515
# Name: StudyHours, Length: 999229, dtype: float64

# %%
#using my own dictionary 
import pandas as pd
pd
student = {
    "Name": ["Gurleen","Rishi","Girish"],
    "Age": [17,18,19],
    "Marks":[20,30,None] ,     # This is a null value
    "City":None     # Another null value
}

# %%
df = pd.DataFrame(student,index=[1,2,3])

# %%
df
# Out:
#       Name  Age  Marks  City
# 1  Gurleen   17   20.0  None
# 2    Rishi   18   30.0  None
# 3   Girish   19    NaN  None

# %%
df['Marks'].fillna(df['Marks'].mean())
# Out:
# 1    20.0
# 2    30.0
# 3    25.0
# Name: Marks, dtype: float64

# %% [markdown]
# ### Task 5: Filter and Display High Scorers

# %%
#As i dont have "Name" and "Marks" column in my dataset therefore i have printed all the rows which have null values

# %%
df=pd.read_csv('validation.csv')

# %%
df.loc[df['TestScore_Math']>80]
# Out:
#         Age  Grade  Gender      Race  SES_Quartile ParentalEducation  \
# 0        14      9  Female  Hispanic             3       SomeCollege
# 4        18     12    Male     Black             3                HS
# 5        18     12    Male  Hispanic             1               <HS
# 6        15     10    Male  Hispanic             4        Bachelors+
# 12       18     12  Female     White             1               <HS
# ...     ...    ...     ...       ...           ...               ...
# 999211   15     10    Male     White             3       SomeCollege
# 999218   18     12  Female  Hispanic             2                HS
# 999222   16     11    Male  Hispanic             4                HS
# 999223   18     12  Female     Black             4        Bachelors+
# 999224   18     12    Male     White             3                HS
#
#        SchoolType    Locale  TestScore_Math  TestScore_Reading  ...       GPA  \
# ...
